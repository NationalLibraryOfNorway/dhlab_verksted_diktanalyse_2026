# %% [markdown]
# # Digital diktanalyse: Mønstre i mengden
#
# _18.februar 2026_
#
# <!-- Ankomst: introduksjon -->
# Velkommen til kodeverksted på Nasjonalbiblioteket!
#
# <!--Presentasjon: hvem er jeg? Hva er konteksten? -->
#
# <!--
# Jeg heter Ingerid Løyning Dale, og jobber som språkteknolog i Språkbanken og DH-laben her på Nasjonalbiblioteket.
# Kodebiblioteket vi kommer til å gå gjennom i dag heter `poetry_analysis` og ble utviklet i samarbeid med Ranveig Kvinnsland fra Ibsensenteret på UiO, i et forskningsprosjekt som heter NORN. Det er et EU-finansiert prosjekt som undersøker nasjonalromantikken i litteraturhistorien.
#
# Vi har sett mest på dikt fra 1890-tallet, altså den såkalt nyromantiske perioden, da vi ikke skrev på nynorsk og bokmål, men landsmål og riksmål, som fortsatt var veldig likt dansk.
# Men det betyr ikke at dere er låst til 1800-tallsdiktning! Koden fungerer på all tekst der linjeskift er brukt for å skille mellom elementene som skal sammenlignes. Vi deler altså ikke teksten inn i setninger, men i linjer, og ser på gjentakelser på tvers av disse linjene.
# -->

# %% [markdown]
# <!-- Agenda -->
# ## Agenda
# I løpet av dette verkstedet skal vi annotere ulike gjentakelsesmønstre i digitale tekster med regelbaserte algoritmer.
#
# Vi skal gå gjennom tre forskjellige lyriske virkemidler som baserer seg på gjentakelser:
# 1. [Enderim](#enderim)
# 2. [Bokstavrim](#bokstavrim)
# 3. [Anafor](#anafor)
#
# Med egne funksjoner for hvert av trekkene kan du blant annet undersøke om det ofte er de samme ordene som rimer på hverandre i enderimsmønstre, om bokstavrim dannes med vokaler eller konsonanter,  og hvilke ord som oftest brukes anaforisk.
#
# <!-- Presentasjon: formål med verktøyet vi bruker, vise frem appen, forklare hvilke lyriske trekk vi ser på og hvordan disse defineres -->

# %% [markdown]
# ## App
# I tillegg til kodebiblioteket, som kan brukes av alle med en pythonversjon høyere enn 3.11, har vi  utviklet en egen app der man kan eksperimentere med enkelttekster og visualisere annotasjonene av gjentakelsesmønstrene:
#
# https://dh.nb.no/run/diktanalyse/app/

# %% [markdown]
# <!--
# Som eksempeldikt til demoen har jeg valgt ut et dikt som passer måneden vi er inne i:
# -->
# ### Eksempeldikt
# > "Februarvise" fra *Høstblomster eller rimstubber* (1896), av Andreas Aabel.

# %%
from pathlib import Path

filepath = Path("eksempeldikt/Februarvise.txt")
text = filepath.read_text()

print(text)
# Out:
# Jeg elsker Februar.
# Om hun kan være knipsk og morsk,
# hun er saa egte norsk.
# aar snøen lyser borti li –
# dikkom, dakkom, dikkom, dikkom dakk –
# da ut paa kjælke, ut paa ski!
# Heiopsan, her er vi!
#
#
# Hun klæder sig med glans.
# Ja hun er vinterns bedste pryd
# og allerstørste fryd.
# Kun tumler sig paa fjord og fjell –
# dikkom, dakkom, dikkom, dikkom dakk! –
# i rennefok og rykemjell;
# men det er moro lell!
#
#
# Av alle systre tolv
# er dig det mindste livsløp undt,
# og rapp din dag gaar rundt.
# men ei vi sakner Solens guld –
# dikkom, dakkom, dikkom, dikkom dakk! –
# naar bare Maanen er os huld,
# helst om han er – lidt fuld.
#
#
# Og i din klare natt,
# naar ingen stor, men mange smaa
# sig tér paa himlens blaa,
# da tindrer vel med deiligt skjær –
# dikkom, dakkom, dikkom, dikkom dakk! –
# din endeløse stjernehær
# og tykkes mig saa nær.
#
#
# Min egen Februar!
# Lad andre vælge sig April
# med dens troløse smil!
# Jeg vælger dig, og til din pris –
# dikkom, dakkom, dikkom, dikkom dakk! –
# jeg synger, mens paa vante vis
# min traver traar din is. –

# %% [markdown]
# ## Enderim
#
# <!-- Enderim:
# - Operasjonalisering
# - fallgruver
# - hva er et nødrim?
# - Er det rim når samme ordet gjentas?
# - Utfordringer: lydlikhet vs. tekstlikhet, sammensatte ord
# - Hvilke ord rimer oftest?
# -->
#
# Enderim definerer vi som stavelsesrim på slutten av en verselinje, altså at siste stavelse på én verselinje rimer på siste stavelse i en annen verselinje.
#
# Les mer om rim i *Store norske leksikon:* https://snl.no/rim

# %% [markdown]
# <!--
# I praksis er koden implementert slik:
# - Vi går gjennom alle verselinjene i en strofe eller et dikt
# - For hver linje starter vi på bakerste bokstav, og sammenligner bokstav for bokstav, med siste ordet på alle tidligere linjer i strofen
# - Dersom det er overlapp mellom to ord, og den delen som overlapper inneholder en vokal, så sier vi at ordene rimer.
# - Da annoterer vi disse linjene med en merkelapp fra alfabetet.
# - Sånn får vi mønstre som ABBA, AABB og ABAB i strofer på fire linjer der to og to av linjene rimer.
# -->

# %%
from poetry_analysis.rhyme_detection import tag_poem_file # type: ignore

# Annoter diktet i tekstfilen med funksjonen "tag_poem_file"
end_rhymes = tag_poem_file(filepath, write_to_file=True)

# %% [markdown]
# Resultatet er en liste med annotasjoner for hver strofe, som igjen inneholder en liste med annotasjoner per linje.
#
# Ved å flate ut den hierarkiske datastrukturen kan vi  laste inn annotasjonene i en dataramme og se nærmere på dem:

# %%
import pandas as pd

# Flat ut listen med annotasjoner og last inn i en dataramme
flattened_data = []
for stanza in end_rhymes:
    stanza_id = stanza['stanza_id']
    rhyme_scheme = stanza['rhyme_scheme']
    for verse in stanza['verses']:
        flat_dict = verse.copy()
        # Disse to linjene bare rydder opp litt og fjerner noen felter vi ikke trenger
        del flat_dict["transcription"]
        del flat_dict["syllables"]
        # Legg til informasjon om strofen på hver av verselinjene
        flat_dict.update({
            'stanza_id': stanza_id,
            'rhyme_scheme': rhyme_scheme,
        })
        flattened_data.append(flat_dict)

# Lag en pandas dataramme
rhyme_df = pd.DataFrame(flattened_data)
rhyme_df
# Out:
#     rhyme_score rhyme_tag                                    text  \
# 0           0.0         a                     Jeg elsker Februar.
# 1           0.0         b        Om hun kan være knipsk og morsk,
# 2           1.0         b                  hun er saa egte norsk.
# 3           0.0         c              aar snøen lyser borti li –
# 4           0.0         d   dikkom, dakkom, dikkom, dikkom dakk –
# 5           1.0         c           da ut paa kjælke, ut paa ski!
# 6           1.0         c                    Heiopsan, her er vi!
# 7           0.0         a               Hun klæder sig med glans.
# 8           0.0         b          Ja hun er vinterns bedste pryd
# 9           1.0         b                   og allerstørste fryd.
# 10          0.0         c     Kun tumler sig paa fjord og fjell –
# 11          0.0         d  dikkom, dakkom, dikkom, dikkom dakk! –
# 12          1.0         c                i rennefok og rykemjell;
# 13          1.0         c                   men det er moro lell!
# 14          0.0         a                     Av alle systre tolv
# 15          0.0         b        er dig det mindste livsløp undt,
# 16          0.5         b             og rapp din dag gaar rundt.
# 17          0.0         c          men ei vi sakner Solens guld –
# 18          0.0         d  dikkom, dakkom, dikkom, dikkom dakk! –
# 19          1.0         c            naar bare Maanen er os huld,
# 20          1.0         c            helst om han er – lidt fuld.
# 21          0.0         a                    Og i din klare natt,
# 22          0.0         b         naar ingen stor, men mange smaa
# 23          1.0         b               sig tér paa himlens blaa,
# 24          0.0         c      da tindrer vel med deiligt skjær –
# 25          0.0         d  dikkom, dakkom, dikkom, dikkom dakk! –
# 26          1.0         c                 din endeløse stjernehær
# 27          1.0         c                  og tykkes mig saa nær.
# 28          0.0         a                       Min egen Februar!
# 29          0.0         b               Lad andre vælge sig April
# 30          1.0         b                  med dens troløse smil!
# 31          0.0         c       Jeg vælger dig, og til din pris –
# 32          0.0         d  dikkom, dakkom, dikkom, dikkom dakk! –
# 33          1.0         c          jeg synger, mens paa vante vis
# 34          0.5         c              min traver traar din is. –
#
#                                        tokens  last_token  rhymes_with  \
# 0                      [jeg, elsker, februar]     februar          NaN
# 1     [om, hun, kan, være, knipsk, og, morsk]       morsk          NaN
# 2                 [hun, er, saa, egte, norsk]       norsk          1.0
# 3              [aar, snøen, lyser, borti, li]          li          NaN
# 4      [dikkom, dakkom, dikkom, dikkom, dakk]        dakk          NaN
# 5         [da, ut, paa, kjælke, ut, paa, ski]         ski          3.0
# 6                     [heiopsan, her, er, vi]          vi          5.0
# 7              [hun, klæder, sig, med, glans]       glans          NaN
# 8       [ja, hun, er, vinterns, bedste, pryd]        pryd          NaN
# 9                    [og, allerstørste, fryd]        fryd          1.0
# 10  [kun, tumler, sig, paa, fjord, og, fjell]       fjell          NaN
# 11     [dikkom, dakkom, dikkom, dikkom, dakk]        dakk          NaN
# 12               [i, rennefok, og, rykemjell]   rykemjell          3.0
# 13                 [men, det, er, moro, lell]        lell          5.0
# 14                   [av, alle, systre, tolv]        tolv          NaN
# 15     [er, dig, det, mindste, livsløp, undt]        undt          NaN
# 16          [og, rapp, din, dag, gaar, rundt]       rundt          1.0
# 17        [men, ei, vi, sakner, solens, guld]        guld          NaN
# 18     [dikkom, dakkom, dikkom, dikkom, dakk]        dakk          NaN
# 19         [naar, bare, maanen, er, os, huld]        huld          3.0
# 20           [helst, om, han, er, lidt, fuld]        fuld          5.0
# 21                  [og, i, din, klare, natt]        natt          NaN
# 22      [naar, ingen, stor, men, mange, smaa]        smaa          NaN
# 23             [sig, tér, paa, himlens, blaa]        blaa          1.0
# 24    [da, tindrer, vel, med, deiligt, skjær]       skjær          NaN
# 25     [dikkom, dakkom, dikkom, dikkom, dakk]        dakk          NaN
# 26                [din, endeløse, stjernehær]  stjernehær          3.0
# 27                [og, tykkes, mig, saa, nær]         nær          5.0
# 28                       [min, egen, februar]     februar          NaN
# 29            [lad, andre, vælge, sig, april]       april          NaN
# 30                 [med, dens, troløse, smil]        smil          1.0
# 31     [jeg, vælger, dig, og, til, din, pris]        pris          NaN
# 32     [dikkom, dakkom, dikkom, dikkom, dakk]        dakk          NaN
# 33       [jeg, synger, mens, paa, vante, vis]         vis          3.0
# 34              [min, traver, traar, din, is]          is          5.0
#
#     verse_id  stanza_id rhyme_scheme
# 0          0          0      abbcdcc
# 1          1          0      abbcdcc
# 2          2          0      abbcdcc
# 3          3          0      abbcdcc
# 4          4          0      abbcdcc
# 5          5          0      abbcdcc
# 6          6          0      abbcdcc
# 7          0          1      abbcdcc
# 8          1          1      abbcdcc
# 9          2          1      abbcdcc
# 10         3          1      abbcdcc
# 11         4          1      abbcdcc
# 12         5          1      abbcdcc
# 13         6          1      abbcdcc
# 14         0          2      abbcdcc
# 15         1          2      abbcdcc
# 16         2          2      abbcdcc
# 17         3          2      abbcdcc
# 18         4          2      abbcdcc
# 19         5          2      abbcdcc
# 20         6          2      abbcdcc
# 21         0          3      abbcdcc
# 22         1          3      abbcdcc
# 23         2          3      abbcdcc
# 24         3          3      abbcdcc
# 25         4          3      abbcdcc
# 26         5          3      abbcdcc
# 27         6          3      abbcdcc
# 28         0          4      abbcdcc
# 29         1          4      abbcdcc
# 30         2          4      abbcdcc
# 31         3          4      abbcdcc
# 32         4          4      abbcdcc
# 33         5          4      abbcdcc
# 34         6          4      abbcdcc

# %% [markdown]
# ### Rimordpar
#
# Finnes det noen rimord som forekommer oftere enn andre i eksempeldiktet vårt?

# %%
def find_rhyming_word(row: pd.Series, df: pd.DataFrame) -> str | None:
    rhyming_word = df["last_token"].to_numpy()[
        (df["stanza_id"] == row["stanza_id"])
        & (df["verse_id"] == row["rhymes_with"])
    ]
    return rhyming_word.item() if rhyming_word.any() else None


def add_rhyming_words(df: pd.DataFrame) -> pd.DataFrame:
    """Legg til kolonnen "rhyming_words" i datarammen `df`."""
    # Gjør om datatypen til verselinjenummeret så den er sammenlignbar med "rhymes_with_syll"
    df.loc[:, "verse_id"] = df["verse_id"].astype(float)
    df["rhyming_word"] = df.apply(
        lambda row: find_rhyming_word(row, df), axis=1
    )
    return df

def find_frequent_rhyme_pairs(df: pd.DataFrame) -> pd.DataFrame:
    df = add_rhyming_words(df)

    rhyming_pairs = df[
        [
            "verse_id",
            "rhymes_with",
            "rhyming_word",
            "last_token",
        ]
    ][df["rhyming_word"].notna()]
    #rhyming_pairs.to_csv("utdata/rimord_eksempeldikt.csv")
    rhyme_groups = (
        rhyming_pairs.groupby("rhyming_word")["last_token"]
        .value_counts()
        .sort_values(ascending=False)
    )
    return rhyme_groups


rhyme_groups = find_frequent_rhyme_pairs(rhyme_df)
rhyme_groups.to_csv("utdata/rimord_frekvens.csv")

rhyme_groups
# Out:
# rhyming_word  last_token
# april         smil          1
# fjell         rykemjell     1
# guld          huld          1
# huld          fuld          1
# li            ski           1
# morsk         norsk         1
# pris          vis           1
# pryd          fryd          1
# rykemjell     lell          1
# ski           vi            1
# skjær         stjernehær    1
# smaa          blaa          1
# stjernehær    nær           1
# undt          rundt         1
# vis           is            1
# Name: count, dtype: int64

# %% [markdown]
# ## Bokstavrim
#
# <!-- Bokstavrim: konsonantisk og vokalisk (men ikke assonans!)  -->
# Bokstavrim, eller alliterasjon, definerer vi som gjentakelsen av en bokstav eller en språklyd i begynnelsen av påfølgende ord.
#
# Med `poetry_analysis` kan vi skille mellom bokstavrim som begynner på samme konsonant eller vokal. Vi har ikke implementert kode for å fange opp såkalt "vokalisk alliterasjon" eller det som kalles assonans, eller halvrim.
#
# Les mer om alliterasjon og assonans:
# - https://snl.no/allitterasjon
# - https://snl.no/assonans

# %% [markdown]
# ### Finn alle bokstavrim

# %%
from poetry_analysis.alliteration import find_line_alliterations

# Vi gjenbruker eksempeldiktet vi lastet inn tidligere i variabelen "text"
alliterations = find_line_alliterations(text, letter_type="both")

alliterations
# Out:
# [['fjord', 'fjell'],
#  ['heiopsan', 'her'],
#  ['huld', 'helst'],
#  ['vante', 'vis'],
#  ['men', 'mange'],
#  ['sakner', 'solens'],
#  ['smaa', 'sig'],
#  ['natt', 'naar'],
#  ['av', 'alle'],
#  ['dikkom', 'dakkom', 'dikkom', 'dikkom', 'dakk', 'da'],
#  ['dikkom', 'dakkom', 'dikkom', 'dikkom', 'dakk'],
#  ['dig', 'det'],
#  ['din', 'dag'],
#  ['dikkom', 'dakkom', 'dikkom', 'dikkom', 'dakk'],
#  ['dikkom', 'dakkom', 'dikkom', 'dikkom', 'dakk', 'din'],
#  ['dikkom', 'dakkom', 'dikkom', 'dikkom', 'dakk'],
#  ['traver', 'traar'],
#  ['rennefok', 'rykemjell']]

# %%
from collections import Counter

# Tell antall ord
unique_words_in_alliterations = len(set([word for words in alliterations for word in words]))
print("Antall unike ord som inngår i bokstavrim i dette diktet: ", unique_words_in_alliterations)

# Finn ordrekka med flest bokstavrim på samme bokstav
top_count = max([len(words) for words in alliterations])

letters= Counter([word[0] for line in alliterations for word in line])

print("Største antall ord som inngår i samme bokstavrim: ", top_count)
print("Bokstaver som inngår i bokstavrimene: " )
letters
# Out:
# Antall unike ord som inngår i bokstavrim i dette diktet:  30
# Største antall ord som inngår i samme bokstavrim:  6
# Bokstaver som inngår i bokstavrimene:
# Counter({'d': 31,
#          'h': 4,
#          's': 4,
#          'f': 2,
#          'v': 2,
#          'm': 2,
#          'n': 2,
#          'a': 2,
#          't': 2,
#          'r': 2})

# %% [markdown]
# ### Finn bare bokstavrim som begynner på konsonanter

# %%
from poetry_analysis.alliteration import find_line_alliterations

# Vi gjenbruker eksempeldiktet vi lastet inn tidligere i variabelen "text"
alliterations = find_line_alliterations(text, letter_type="consonant")

alliterations
# Out:
# [['fjord', 'fjell'],
#  ['heiopsan', 'her'],
#  ['huld', 'helst'],
#  ['vante', 'vis'],
#  ['men', 'mange'],
#  ['sakner', 'solens'],
#  ['smaa', 'sig'],
#  ['natt', 'naar'],
#  ['dikkom', 'dakkom', 'dikkom', 'dikkom', 'dakk', 'da'],
#  ['dikkom', 'dakkom', 'dikkom', 'dikkom', 'dakk'],
#  ['dig', 'det'],
#  ['din', 'dag'],
#  ['dikkom', 'dakkom', 'dikkom', 'dikkom', 'dakk'],
#  ['dikkom', 'dakkom', 'dikkom', 'dikkom', 'dakk', 'din'],
#  ['dikkom', 'dakkom', 'dikkom', 'dikkom', 'dakk'],
#  ['traver', 'traar'],
#  ['rennefok', 'rykemjell']]

# %% [markdown]
# ### Finn bare bokstavrim som begynner på vokaler

# %%
alliterations = find_line_alliterations(text, letter_type="vowel")

alliterations
# Out:
# [['av', 'alle']]

# %% [markdown]
# ## Anafor
#
# <!--Anafor: gjentakende ord, frase i starten av leddsetninger eller linjer -->
#
# Anafor definerer vi som gjentakende ord eller fraser i begynnelsen av påfølgende verselinjer.
#
# Les mer om anafor: https://snl.no/anafor

# %% [markdown]
# Funksjonen `extract_anaphora` henter ut henholdsvis uni-, bi-, tri- og firegrammer fra påfølgende linjer

# %%
from poetry_analysis.anaphora import extract_anaphora

anaphora_ngrams = extract_anaphora(text)
anaphora_ngrams
# Out:
# {'1-grams': {'jeg': 3,
#   'hun': 2,
#   'dikkom': 5,
#   'da': 2,
#   'og': 4,
#   'men': 2,
#   'naar': 2,
#   'min': 2},
#  '2-grams': {'dikkom dakkom': 5},
#  '3-grams': {'dikkom dakkom dikkom': 5},
#  '4-grams': {'dikkom dakkom dikkom dikkom': 5}}

# %% [markdown]
# Funksjonen `extract_line_anaphora` henter ut fraser som gjentar seg på samme linje

# %%
from poetry_analysis.anaphora import extract_line_anaphora

line_anaphora = extract_line_anaphora(text)

line_anaphora
# Out:
# [{'line_id': 4, 'phrase': 'dikkom', 'count': 3},
#  {'line_id': 13, 'phrase': 'dikkom', 'count': 3},
#  {'line_id': 22, 'phrase': 'dikkom', 'count': 3},
#  {'line_id': 31, 'phrase': 'dikkom', 'count': 3},
#  {'line_id': 40, 'phrase': 'dikkom', 'count': 3}]

# %% [markdown]
# ## Hvordan undersøke mange tekster samtidig?
#
# Vi kan jo lett se gjentakelsesmønstrene selv når vi ser på én tekst av gangen, men hva om du har tusenvis?
#
# Ta for eksempel korpuset [NORN Dikt](https://github.com/norn-uio/norn-poems) som har over 3000 korrekturleste dikt og som jeg har lastet inn i en jsonl-fil:  `norn_poems.jsonl`.
# Filen `metadata.jsonl` inneholder bibliografisk informasjon om bøkene som diktene er publisert i.

# %%
import pandas as pd

# Last inn i en pandas dataramme
textdata = pd.read_json("norn_poems.jsonl", lines=True)
meta = pd.read_json("metadata.jsonl", lines=True)

df = meta.merge(textdata, on="poem_id")

# %% [markdown]
# ### Enderim på mange tekster

# %% [markdown]
# Så kan vi bruke funksjonen `tag_text` på datarammen for å annotere enderimene:

# %%
from poetry_analysis.rhyme_detection import tag_text

df["end_rhymes"] = df.text.apply(lambda t: list(tag_text(t)))

# %% [markdown]
# Resultatet er et nøstet hierarki av strofer og linjer og annotasjoner som hører til, så vi flater det ut med `pandas.json_normalize`:

# %%
all_records = []

for _, row in df.iterrows():
    # Normaliser annotasjonsstrukturen for hver rad
    normalized = pd.json_normalize(
        row["end_rhymes"],
        record_path="verses",
        meta=["stanza_id", "rhyme_scheme"],
    )
    # Legg til dikt-ID så vi beholder koblingen til metadata
    normalized["poem_id"] = row["poem_id"]
    all_records.append(normalized)

# Slå sammen alle radene
expanded = pd.concat(all_records, ignore_index=True)

# %%
# Se på de fem første radene i datarammen med .head()
expanded.head()
# Out:
#    rhyme_score rhyme_tag                              text transcription  \
# 0          0.0         a  Ungdomsslægt, som fremad stevner
# 1          0.0         b               mod et sikkert mål,
# 2          1.0         a    ungdomssind, som alting levner
# 3          1.0         b            fast som hærdet stål ;
# 4          0.0         c     ungdomsslægt med store tanker
#
#                                  tokens syllables last_token rhymes_with  \
# 0  [ungdomsslægt, som, fremad, stevner]      None    stevner         NaN
# 1               [mod, et, sikkert, mål]      None        mål         NaN
# 2    [ungdomssind, som, alting, levner]      None     levner         0.0
# 3             [fast, som, hærdet, stål]      None       stål         1.0
# 4    [ungdomsslægt, med, store, tanker]      None     tanker         NaN
#
#    verse_id stanza_id rhyme_scheme  poem_id
# 0         0         0     ababcdcd     2641
# 1         1         0     ababcdcd     2641
# 2         2         0     ababcdcd     2641
# 3         3         0     ababcdcd     2641
# 4         4         0     ababcdcd     2641

# %% [markdown]
# ### Hvilke anaforer forekommer oftest?

# %%
from poetry_analysis.anaphora import construct_anaphora_df

anaphora_df = construct_anaphora_df(expanded, anaphora_length=3)

# %%
anaphora_df.phrase.value_counts()
# Out:
# phrase
# og det er         5
# golgathamanden    5
# kom og hjælp      5
# seier skal vi     3
# det er som        3
#                  ..
# husk på det       1
# jeg synes at      1
# for dig betød     1
# saa det er        1
# mon dette var     1
# Name: count, Length: 340, dtype: int64

# %% [markdown]
# ## Hvordan undersøke egne tekster?

# %%
# Definer stien til en mappe og kjør funksjonene på hver av tekstene

# %%
dirpath=Path("eksempeldikt")

results = []
for file in dirpath.iterdir(): 
    rhymes = tag_poem_file(file)
    results.append(rhymes)

# %%
results
# Out:
# [[{'stanza_id': 0,
#    'rhyme_scheme': 'abcd',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Et Aar idag!',
#      'transcription': '',
#      'tokens': ['et', 'aar', 'idag'],
#      'syllables': None,
#      'last_token': 'idag',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'Du store miu,',
#      'transcription': '',
#      'tokens': ['du', 'store', 'miu'],
#      'syllables': None,
#      'last_token': 'miu',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'saa tyk og rød',
#      'transcription': '',
#      'tokens': ['saa', 'tyk', 'og', 'rød'],
#      'syllables': None,
#      'last_token': 'rød',
#      'rhymes_with': None,
#      'verse_id': 2},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'd',
#      'text': 'og fed og fin!',
#      'transcription': '',
#      'tokens': ['og', 'fed', 'og', 'fin'],
#      'syllables': None,
#      'last_token': 'fin',
#      'rhymes_with': None,
#      'verse_id': 3}]},
#   {'stanza_id': 1,
#    'rhyme_scheme': 'abbb',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Paa Ære, Gut,',
#      'transcription': '',
#      'tokens': ['paa', 'ære', 'gut'],
#      'syllables': None,
#      'last_token': 'gut',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'du vokset har',
#      'transcription': '',
#      'tokens': ['du', 'vokset', 'har'],
#      'syllables': None,
#      'last_token': 'har',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'b',
#      'text': 'fra Februar',
#      'transcription': '',
#      'tokens': ['fra', 'februar'],
#      'syllables': None,
#      'last_token': 'februar',
#      'rhymes_with': 1,
#      'verse_id': 2},
#     {'rhyme_score': 0.5,
#      'rhyme_tag': 'b',
#      'text': 'til Februar.',
#      'transcription': '',
#      'tokens': ['til', 'februar'],
#      'syllables': None,
#      'last_token': 'februar',
#      'rhymes_with': 2,
#      'verse_id': 3}]},
#   {'stanza_id': 2,
#    'rhyme_scheme': 'abcb',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Thi ungefær',
#      'transcription': '',
#      'tokens': ['thi', 'ungefær'],
#      'syllables': None,
#      'last_token': 'ungefær',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'ved denne Tid',
#      'transcription': '',
#      'tokens': ['ved', 'denne', 'tid'],
#      'syllables': None,
#      'last_token': 'tid',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'ifjor du var',
#      'transcription': '',
#      'tokens': ['ifjor', 'du', 'var'],
#      'syllables': None,
#      'last_token': 'var',
#      'rhymes_with': None,
#      'verse_id': 2},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'b',
#      'text': '“a wee, wee kid.”',
#      'transcription': '',
#      'tokens': ['“', 'a', 'wee', 'wee', 'kid'],
#      'syllables': None,
#      'last_token': 'kid',
#      'rhymes_with': 1,
#      'verse_id': 3}]},
#   {'stanza_id': 3,
#    'rhyme_scheme': 'abba',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Nuvel! du har',
#      'transcription': '',
#      'tokens': ['nuvel', 'du', 'har'],
#      'syllables': None,
#      'last_token': 'har',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'at slægte paa.',
#      'transcription': '',
#      'tokens': ['at', 'slægte', 'paa'],
#      'syllables': None,
#      'last_token': 'paa',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'b',
#      'text': 'Om godt? Naa, naa,',
#      'transcription': '',
#      'tokens': ['om', 'godt', 'naa', 'naa'],
#      'syllables': None,
#      'last_token': 'naa',
#      'rhymes_with': 1,
#      'verse_id': 2},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'a',
#      'text': "som man det ta'r!",
#      'transcription': '',
#      'tokens': ['som', 'man', 'det', 'tar'],
#      'syllables': None,
#      'last_token': 'tar',
#      'rhymes_with': 0,
#      'verse_id': 3}]},
#   {'stanza_id': 4,
#    'rhyme_scheme': 'abcb',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Men vil du bli',
#      'transcription': '',
#      'tokens': ['men', 'vil', 'du', 'bli'],
#      'syllables': None,
#      'last_token': 'bli',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'en dygtig Kar,',
#      'transcription': '',
#      'tokens': ['en', 'dygtig', 'kar'],
#      'syllables': None,
#      'last_token': 'kar',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'saa tro du mig,',
#      'transcription': '',
#      'tokens': ['saa', 'tro', 'du', 'mig'],
#      'syllables': None,
#      'last_token': 'mig',
#      'rhymes_with': None,
#      'verse_id': 2},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'b',
#      'text': "bliv lig din Fa'r!",
#      'transcription': '',
#      'tokens': ['bliv', 'lig', 'din', 'far'],
#      'syllables': None,
#      'last_token': 'far',
#      'rhymes_with': 1,
#      'verse_id': 3}]},
#   {'stanza_id': 5,
#    'rhyme_scheme': 'abac',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Og vil du naa',
#      'transcription': '',
#      'tokens': ['og', 'vil', 'du', 'naa'],
#      'syllables': None,
#      'last_token': 'naa',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'ret høit paa Jord,',
#      'transcription': '',
#      'tokens': ['ret', 'høit', 'paa', 'jord'],
#      'syllables': None,
#      'last_token': 'jord',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'a',
#      'text': 'du lyde maa',
#      'transcription': '',
#      'tokens': ['du', 'lyde', 'maa'],
#      'syllables': None,
#      'last_token': 'maa',
#      'rhymes_with': 0,
#      'verse_id': 2},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': "din Fa'r og Mo'r.",
#      'transcription': '',
#      'tokens': ['din', 'far', 'og', 'mor'],
#      'syllables': None,
#      'last_token': 'mor',
#      'rhymes_with': None,
#      'verse_id': 3}]},
#   {'stanza_id': 6,
#    'rhyme_scheme': 'abcb',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Du slaar nok til dig',
#      'transcription': '',
#      'tokens': ['du', 'slaar', 'nok', 'til', 'dig'],
#      'syllables': None,
#      'last_token': 'dig',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'Fod for Fod;',
#      'transcription': '',
#      'tokens': ['fod', 'for', 'fod'],
#      'syllables': None,
#      'last_token': 'fod',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'du bærer vist',
#      'transcription': '',
#      'tokens': ['du', 'bærer', 'vist'],
#      'syllables': None,
#      'last_token': 'vist',
#      'rhymes_with': None,
#      'verse_id': 2},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'b',
#      'text': 'paa Slægtens Blod.',
#      'transcription': '',
#      'tokens': ['paa', 'slægtens', 'blod'],
#      'syllables': None,
#      'last_token': 'blod',
#      'rhymes_with': 1,
#      'verse_id': 3}]},
#   {'stanza_id': 7,
#    'rhyme_scheme': 'abcd',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Men hvad du gjør,',
#      'transcription': '',
#      'tokens': ['men', 'hvad', 'du', 'gjør'],
#      'syllables': None,
#      'last_token': 'gjør',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'bliv stor og snil,',
#      'transcription': '',
#      'tokens': ['bliv', 'stor', 'og', 'snil'],
#      'syllables': None,
#      'last_token': 'snil',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'min kjære Edmund',
#      'transcription': '',
#      'tokens': ['min', 'kjære', 'edmund'],
#      'syllables': None,
#      'last_token': 'edmund',
#      'rhymes_with': None,
#      'verse_id': 2},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'd',
#      'text': 'Thorstein Field.',
#      'transcription': '',
#      'tokens': ['thorstein', 'field'],
#      'syllables': None,
#      'last_token': 'field',
#      'rhymes_with': None,
#      'verse_id': 3}]}],
#  [{'stanza_id': 0,
#    'rhyme_scheme': 'abbcdcc',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Jeg elsker Februar.',
#      'transcription': '',
#      'tokens': ['jeg', 'elsker', 'februar'],
#      'syllables': None,
#      'last_token': 'februar',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'Om hun kan være knipsk og morsk,',
#      'transcription': '',
#      'tokens': ['om', 'hun', 'kan', 'være', 'knipsk', 'og', 'morsk'],
#      'syllables': None,
#      'last_token': 'morsk',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'b',
#      'text': 'hun er saa egte norsk.',
#      'transcription': '',
#      'tokens': ['hun', 'er', 'saa', 'egte', 'norsk'],
#      'syllables': None,
#      'last_token': 'norsk',
#      'rhymes_with': 1,
#      'verse_id': 2},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'aar snøen lyser borti li –',
#      'transcription': '',
#      'tokens': ['aar', 'snøen', 'lyser', 'borti', 'li'],
#      'syllables': None,
#      'last_token': 'li',
#      'rhymes_with': None,
#      'verse_id': 3},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'd',
#      'text': 'dikkom, dakkom, dikkom, dikkom dakk –',
#      'transcription': '',
#      'tokens': ['dikkom', 'dakkom', 'dikkom', 'dikkom', 'dakk'],
#      'syllables': None,
#      'last_token': 'dakk',
#      'rhymes_with': None,
#      'verse_id': 4},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'c',
#      'text': 'da ut paa kjælke, ut paa ski!',
#      'transcription': '',
#      'tokens': ['da', 'ut', 'paa', 'kjælke', 'ut', 'paa', 'ski'],
#      'syllables': None,
#      'last_token': 'ski',
#      'rhymes_with': 3,
#      'verse_id': 5},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'c',
#      'text': 'Heiopsan, her er vi!',
#      'transcription': '',
#      'tokens': ['heiopsan', 'her', 'er', 'vi'],
#      'syllables': None,
#      'last_token': 'vi',
#      'rhymes_with': 5,
#      'verse_id': 6}]},
#   {'stanza_id': 1,
#    'rhyme_scheme': 'abbcdcc',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Hun klæder sig med glans.',
#      'transcription': '',
#      'tokens': ['hun', 'klæder', 'sig', 'med', 'glans'],
#      'syllables': None,
#      'last_token': 'glans',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'Ja hun er vinterns bedste pryd',
#      'transcription': '',
#      'tokens': ['ja', 'hun', 'er', 'vinterns', 'bedste', 'pryd'],
#      'syllables': None,
#      'last_token': 'pryd',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'b',
#      'text': 'og allerstørste fryd.',
#      'transcription': '',
#      'tokens': ['og', 'allerstørste', 'fryd'],
#      'syllables': None,
#      'last_token': 'fryd',
#      'rhymes_with': 1,
#      'verse_id': 2},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'Kun tumler sig paa fjord og fjell –',
#      'transcription': '',
#      'tokens': ['kun', 'tumler', 'sig', 'paa', 'fjord', 'og', 'fjell'],
#      'syllables': None,
#      'last_token': 'fjell',
#      'rhymes_with': None,
#      'verse_id': 3},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'd',
#      'text': 'dikkom, dakkom, dikkom, dikkom dakk! –',
#      'transcription': '',
#      'tokens': ['dikkom', 'dakkom', 'dikkom', 'dikkom', 'dakk'],
#      'syllables': None,
#      'last_token': 'dakk',
#      'rhymes_with': None,
#      'verse_id': 4},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'c',
#      'text': 'i rennefok og rykemjell;',
#      'transcription': '',
#      'tokens': ['i', 'rennefok', 'og', 'rykemjell'],
#      'syllables': None,
#      'last_token': 'rykemjell',
#      'rhymes_with': 3,
#      'verse_id': 5},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'c',
#      'text': 'men det er moro lell!',
#      'transcription': '',
#      'tokens': ['men', 'det', 'er', 'moro', 'lell'],
#      'syllables': None,
#      'last_token': 'lell',
#      'rhymes_with': 5,
#      'verse_id': 6}]},
#   {'stanza_id': 2,
#    'rhyme_scheme': 'abbcdcc',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Av alle systre tolv',
#      'transcription': '',
#      'tokens': ['av', 'alle', 'systre', 'tolv'],
#      'syllables': None,
#      'last_token': 'tolv',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'er dig det mindste livsløp undt,',
#      'transcription': '',
#      'tokens': ['er', 'dig', 'det', 'mindste', 'livsløp', 'undt'],
#      'syllables': None,
#      'last_token': 'undt',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 0.5,
#      'rhyme_tag': 'b',
#      'text': 'og rapp din dag gaar rundt.',
#      'transcription': '',
#      'tokens': ['og', 'rapp', 'din', 'dag', 'gaar', 'rundt'],
#      'syllables': None,
#      'last_token': 'rundt',
#      'rhymes_with': 1,
#      'verse_id': 2},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'men ei vi sakner Solens guld –',
#      'transcription': '',
#      'tokens': ['men', 'ei', 'vi', 'sakner', 'solens', 'guld'],
#      'syllables': None,
#      'last_token': 'guld',
#      'rhymes_with': None,
#      'verse_id': 3},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'd',
#      'text': 'dikkom, dakkom, dikkom, dikkom dakk! –',
#      'transcription': '',
#      'tokens': ['dikkom', 'dakkom', 'dikkom', 'dikkom', 'dakk'],
#      'syllables': None,
#      'last_token': 'dakk',
#      'rhymes_with': None,
#      'verse_id': 4},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'c',
#      'text': 'naar bare Maanen er os huld,',
#      'transcription': '',
#      'tokens': ['naar', 'bare', 'maanen', 'er', 'os', 'huld'],
#      'syllables': None,
#      'last_token': 'huld',
#      'rhymes_with': 3,
#      'verse_id': 5},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'c',
#      'text': 'helst om han er – lidt fuld.',
#      'transcription': '',
#      'tokens': ['helst', 'om', 'han', 'er', 'lidt', 'fuld'],
#      'syllables': None,
#      'last_token': 'fuld',
#      'rhymes_with': 5,
#      'verse_id': 6}]},
#   {'stanza_id': 3,
#    'rhyme_scheme': 'abbcdcc',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Og i din klare natt,',
#      'transcription': '',
#      'tokens': ['og', 'i', 'din', 'klare', 'natt'],
#      'syllables': None,
#      'last_token': 'natt',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'naar ingen stor, men mange smaa',
#      'transcription': '',
#      'tokens': ['naar', 'ingen', 'stor', 'men', 'mange', 'smaa'],
#      'syllables': None,
#      'last_token': 'smaa',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'b',
#      'text': 'sig tér paa himlens blaa,',
#      'transcription': '',
#      'tokens': ['sig', 'tér', 'paa', 'himlens', 'blaa'],
#      'syllables': None,
#      'last_token': 'blaa',
#      'rhymes_with': 1,
#      'verse_id': 2},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'da tindrer vel med deiligt skjær –',
#      'transcription': '',
#      'tokens': ['da', 'tindrer', 'vel', 'med', 'deiligt', 'skjær'],
#      'syllables': None,
#      'last_token': 'skjær',
#      'rhymes_with': None,
#      'verse_id': 3},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'd',
#      'text': 'dikkom, dakkom, dikkom, dikkom dakk! –',
#      'transcription': '',
#      'tokens': ['dikkom', 'dakkom', 'dikkom', 'dikkom', 'dakk'],
#      'syllables': None,
#      'last_token': 'dakk',
#      'rhymes_with': None,
#      'verse_id': 4},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'c',
#      'text': 'din endeløse stjernehær',
#      'transcription': '',
#      'tokens': ['din', 'endeløse', 'stjernehær'],
#      'syllables': None,
#      'last_token': 'stjernehær',
#      'rhymes_with': 3,
#      'verse_id': 5},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'c',
#      'text': 'og tykkes mig saa nær.',
#      'transcription': '',
#      'tokens': ['og', 'tykkes', 'mig', 'saa', 'nær'],
#      'syllables': None,
#      'last_token': 'nær',
#      'rhymes_with': 5,
#      'verse_id': 6}]},
#   {'stanza_id': 4,
#    'rhyme_scheme': 'abbcdcc',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Min egen Februar!',
#      'transcription': '',
#      'tokens': ['min', 'egen', 'februar'],
#      'syllables': None,
#      'last_token': 'februar',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'Lad andre vælge sig April',
#      'transcription': '',
#      'tokens': ['lad', 'andre', 'vælge', 'sig', 'april'],
#      'syllables': None,
#      'last_token': 'april',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'b',
#      'text': 'med dens troløse smil!',
#      'transcription': '',
#      'tokens': ['med', 'dens', 'troløse', 'smil'],
#      'syllables': None,
#      'last_token': 'smil',
#      'rhymes_with': 1,
#      'verse_id': 2},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'Jeg vælger dig, og til din pris –',
#      'transcription': '',
#      'tokens': ['jeg', 'vælger', 'dig', 'og', 'til', 'din', 'pris'],
#      'syllables': None,
#      'last_token': 'pris',
#      'rhymes_with': None,
#      'verse_id': 3},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'd',
#      'text': 'dikkom, dakkom, dikkom, dikkom dakk! –',
#      'transcription': '',
#      'tokens': ['dikkom', 'dakkom', 'dikkom', 'dikkom', 'dakk'],
#      'syllables': None,
#      'last_token': 'dakk',
#      'rhymes_with': None,
#      'verse_id': 4},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'c',
#      'text': 'jeg synger, mens paa vante vis',
#      'transcription': '',
#      'tokens': ['jeg', 'synger', 'mens', 'paa', 'vante', 'vis'],
#      'syllables': None,
#      'last_token': 'vis',
#      'rhymes_with': 3,
#      'verse_id': 5},
#     {'rhyme_score': 0.5,
#      'rhyme_tag': 'c',
#      'text': 'min traver traar din is. –',
#      'transcription': '',
#      'tokens': ['min', 'traver', 'traar', 'din', 'is'],
#      'syllables': None,
#      'last_token': 'is',
#      'rhymes_with': 5,
#      'verse_id': 6}]}],
#  [{'stanza_id': 0,
#    'rhyme_scheme': 'abcddc',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Men dybt ind under Sneens frosne Hvælv',
#      'transcription': '',
#      'tokens': ['men', 'dybt', 'ind', 'under', 'sneens', 'frosne', 'hvælv'],
#      'syllables': None,
#      'last_token': 'hvælv',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'gaar med sit Vaarsus Kjærlighedens Elv,',
#      'transcription': '',
#      'tokens': ['gaar', 'med', 'sit', 'vaarsus', 'kjærlighedens', 'elv'],
#      'syllables': None,
#      'last_token': 'elv',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'tyst famlende sig Vei ad nye Baner',
#      'transcription': '',
#      'tokens': ['tyst', 'famlende', 'sig', 'vei', 'ad', 'nye', 'baner'],
#      'syllables': None,
#      'last_token': 'baner',
#      'rhymes_with': None,
#      'verse_id': 2},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'd',
#      'text': 'og standser, hulker eller risler sødt,',
#      'transcription': '',
#      'tokens': ['og', 'standser', 'hulker', 'eller', 'risler', 'sødt'],
#      'syllables': None,
#      'last_token': 'sødt',
#      'rhymes_with': None,
#      'verse_id': 3},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'd',
#      'text': 'af ubevidste Lykkelængsler født, ‒',
#      'transcription': '',
#      'tokens': ['af', 'ubevidste', 'lykkelængsler', 'født'],
#      'syllables': None,
#      'last_token': 'født',
#      'rhymes_with': 3,
#      'verse_id': 4},
#     {'rhyme_score': 0.5,
#      'rhyme_tag': 'c',
#      'text': 'snart smelter Sneen, før hun selv det aner.',
#      'transcription': '',
#      'tokens': ['snart',
#       'smelter',
#       'sneen',
#       'før',
#       'hun',
#       'selv',
#       'det',
#       'aner'],
#      'syllables': None,
#      'last_token': 'aner',
#      'rhymes_with': 2,
#      'verse_id': 5}]},
#   {'stanza_id': 1,
#    'rhyme_scheme': 'aabccb',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Og se, nys sprang i Solens Skin den fri',
#      'transcription': '',
#      'tokens': ['og',
#       'se',
#       'nys',
#       'sprang',
#       'i',
#       'solens',
#       'skin',
#       'den',
#       'fri'],
#      'syllables': None,
#      'last_token': 'fri',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'a',
#      'text': 'og silrer nu saa morgenblank forbi',
#      'transcription': '',
#      'tokens': ['og', 'silrer', 'nu', 'saa', 'morgenblank', 'forbi'],
#      'syllables': None,
#      'last_token': 'forbi',
#      'rhymes_with': 0,
#      'verse_id': 1},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'den første Vaarblomst, tindrende af Glæde.',
#      'transcription': '',
#      'tokens': ['den', 'første', 'vaarblomst', 'tindrende', 'af', 'glæde'],
#      'syllables': None,
#      'last_token': 'glæde',
#      'rhymes_with': None,
#      'verse_id': 2},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'Hun bryder Blomsten, der i Sol den staar,',
#      'transcription': '',
#      'tokens': ['hun',
#       'bryder',
#       'blomsten',
#       'der',
#       'i',
#       'sol',
#       'den',
#       'staar'],
#      'syllables': None,
#      'last_token': 'staar',
#      'rhymes_with': None,
#      'verse_id': 3},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'c',
#      'text': 'men kjender Smærten bare dobbelt saar',
#      'transcription': '',
#      'tokens': ['men', 'kjender', 'smærten', 'bare', 'dobbelt', 'saar'],
#      'syllables': None,
#      'last_token': 'saar',
#      'rhymes_with': 3,
#      'verse_id': 4},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'b',
#      'text': 'og kaster den i Græmmelse og Lede.',
#      'transcription': '',
#      'tokens': ['og', 'kaster', 'den', 'i', 'græmmelse', 'og', 'lede'],
#      'syllables': None,
#      'last_token': 'lede',
#      'rhymes_with': 2,
#      'verse_id': 5}]},
#   {'stanza_id': 2,
#    'rhyme_scheme': 'aabccb',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Ak, hvorfor elske, hvorfor haabe, tro,',
#      'transcription': '',
#      'tokens': ['ak', 'hvorfor', 'elske', 'hvorfor', 'haabe', 'tro'],
#      'syllables': None,
#      'last_token': 'tro',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'a',
#      'text': 'naar ikkun Sorg og Minders Gift vil gro',
#      'transcription': '',
#      'tokens': ['naar',
#       'ikkun',
#       'sorg',
#       'og',
#       'minders',
#       'gift',
#       'vil',
#       'gro'],
#      'syllables': None,
#      'last_token': 'gro',
#      'rhymes_with': 0,
#      'verse_id': 1},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'af det, som burde Livets Kræfter hæve! ‒',
#      'transcription': '',
#      'tokens': ['af', 'det', 'som', 'burde', 'livets', 'kræfter', 'hæve'],
#      'syllables': None,
#      'last_token': 'hæve',
#      'rhymes_with': None,
#      'verse_id': 2},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'Og ud hun ser, hvor Aftnen fin og rød',
#      'transcription': '',
#      'tokens': ['og',
#       'ud',
#       'hun',
#       'ser',
#       'hvor',
#       'aftnen',
#       'fin',
#       'og',
#       'rød'],
#      'syllables': None,
#      'last_token': 'rød',
#      'rhymes_with': None,
#      'verse_id': 3},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'c',
#      'text': 'nu synker underlig og længselsblød,',
#      'transcription': '',
#      'tokens': ['nu', 'synker', 'underlig', 'og', 'længselsblød'],
#      'syllables': None,
#      'last_token': 'længselsblød',
#      'rhymes_with': 3,
#      'verse_id': 4},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'b',
#      'text': 'saa ømt hun føler Hjærtets Strenge bæve.',
#      'transcription': '',
#      'tokens': ['saa', 'ømt', 'hun', 'føler', 'hjærtets', 'strenge', 'bæve'],
#      'syllables': None,
#      'last_token': 'bæve',
#      'rhymes_with': 2,
#      'verse_id': 5}]},
#   {'stanza_id': 3,
#    'rhyme_scheme': 'aabcdb',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Hun tænker paa, hvor tillidsfuldt hun gav',
#      'transcription': '',
#      'tokens': ['hun', 'tænker', 'paa', 'hvor', 'tillidsfuldt', 'hun', 'gav'],
#      'syllables': None,
#      'last_token': 'gav',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'a',
#      'text': 'af al sin Overflod og uden Krav,',
#      'transcription': '',
#      'tokens': ['af', 'al', 'sin', 'overflod', 'og', 'uden', 'krav'],
#      'syllables': None,
#      'last_token': 'krav',
#      'rhymes_with': 0,
#      'verse_id': 1},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'kun fyldt med Tak, kun salig ved at give;',
#      'transcription': '',
#      'tokens': ['kun',
#       'fyldt',
#       'med',
#       'tak',
#       'kun',
#       'salig',
#       'ved',
#       'at',
#       'give'],
#      'syllables': None,
#      'last_token': 'give',
#      'rhymes_with': None,
#      'verse_id': 2},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'og ei hun fatter det til denne Stund:',
#      'transcription': '',
#      'tokens': ['og', 'ei', 'hun', 'fatter', 'det', 'til', 'denne', 'stund'],
#      'syllables': None,
#      'last_token': 'stund',
#      'rhymes_with': None,
#      'verse_id': 3},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'd',
#      'text': 'Jo mer hun gav, des mere rig var hun,',
#      'transcription': '',
#      'tokens': ['jo', 'mer', 'hun', 'gav', 'des', 'mere', 'rig', 'var', 'hun'],
#      'syllables': None,
#      'last_token': 'hun',
#      'rhymes_with': None,
#      'verse_id': 4},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'b',
#      'text': 'var hun, som dog saa fattig skulde blive.',
#      'transcription': '',
#      'tokens': ['var',
#       'hun',
#       'som',
#       'dog',
#       'saa',
#       'fattig',
#       'skulde',
#       'blive'],
#      'syllables': None,
#      'last_token': 'blive',
#      'rhymes_with': 2,
#      'verse_id': 5}]},
#   {'stanza_id': 4,
#    'rhyme_scheme': 'abcdef',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Og som et Hjærte, overfyldt og træt,',
#      'transcription': '',
#      'tokens': ['og', 'som', 'et', 'hjærte', 'overfyldt', 'og', 'træt'],
#      'syllables': None,
#      'last_token': 'træt',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'blot græde kan, slig har hun ogsaa grædt',
#      'transcription': '',
#      'tokens': ['blot',
#       'græde',
#       'kan',
#       'slig',
#       'har',
#       'hun',
#       'ogsaa',
#       'grædt'],
#      'syllables': None,
#      'last_token': 'grædt',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'sig alle Tanker sløvede og blinde',
#      'transcription': '',
#      'tokens': ['sig', 'alle', 'tanker', 'sløvede', 'og', 'blinde'],
#      'syllables': None,
#      'last_token': 'blinde',
#      'rhymes_with': None,
#      'verse_id': 2},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'd',
#      'text': 'og ønsket, at det aldrig mer blev Vaar,',
#      'transcription': '',
#      'tokens': ['og', 'ønsket', 'at', 'det', 'aldrig', 'mer', 'blev', 'vaar'],
#      'syllables': None,
#      'last_token': 'vaar',
#      'rhymes_with': None,
#      'verse_id': 3},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'e',
#      'text': 'men Vinter kun og helst saa kold og haard,',
#      'transcription': '',
#      'tokens': ['men',
#       'vinter',
#       'kun',
#       'og',
#       'helst',
#       'saa',
#       'kold',
#       'og',
#       'haard'],
#      'syllables': None,
#      'last_token': 'haard',
#      'rhymes_with': None,
#      'verse_id': 4},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'f',
#      'text': 'saa streng, at intet Løvspring turde skinne.',
#      'transcription': '',
#      'tokens': ['saa',
#       'streng',
#       'at',
#       'intet',
#       'løvspring',
#       'turde',
#       'skinne'],
#      'syllables': None,
#      'last_token': 'skinne',
#      'rhymes_with': None,
#      'verse_id': 5}]},
#   {'stanza_id': 5,
#    'rhyme_scheme': 'aabcdb',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Og atter falder Sneen tæt og tung',
#      'transcription': '',
#      'tokens': ['og', 'atter', 'falder', 'sneen', 'tæt', 'og', 'tung'],
#      'syllables': None,
#      'last_token': 'tung',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0.5,
#      'rhyme_tag': 'a',
#      'text': 'og kvæler hvert et Skud; men hun er ung',
#      'transcription': '',
#      'tokens': ['og',
#       'kvæler',
#       'hvert',
#       'et',
#       'skud',
#       'men',
#       'hun',
#       'er',
#       'ung'],
#      'syllables': None,
#      'last_token': 'ung',
#      'rhymes_with': 0,
#      'verse_id': 1},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'og yngre kanske, end hun selv det aner,',
#      'transcription': '',
#      'tokens': ['og', 'yngre', 'kanske', 'end', 'hun', 'selv', 'det', 'aner'],
#      'syllables': None,
#      'last_token': 'aner',
#      'rhymes_with': None,
#      'verse_id': 2},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'og dybt ind under Sneens frosne Hvælv',
#      'transcription': '',
#      'tokens': ['og', 'dybt', 'ind', 'under', 'sneens', 'frosne', 'hvælv'],
#      'syllables': None,
#      'last_token': 'hvælv',
#      'rhymes_with': None,
#      'verse_id': 3},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'd',
#      'text': 'gaar med sit Vaarsus Kjærlighedens Elv,',
#      'transcription': '',
#      'tokens': ['gaar', 'med', 'sit', 'vaarsus', 'kjærlighedens', 'elv'],
#      'syllables': None,
#      'last_token': 'elv',
#      'rhymes_with': None,
#      'verse_id': 4},
#     {'rhyme_score': 0.5,
#      'rhyme_tag': 'b',
#      'text': 'stilt famlende sig Vei ad nye Baner.',
#      'transcription': '',
#      'tokens': ['stilt', 'famlende', 'sig', 'vei', 'ad', 'nye', 'baner'],
#      'syllables': None,
#      'last_token': 'baner',
#      'rhymes_with': 2,
#      'verse_id': 5}]}],
#  [{'stanza_id': 0,
#    'rhyme_scheme': 'abcb',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Ind under Himlen, den blaa, der synes',
#      'transcription': '',
#      'tokens': ['ind', 'under', 'himlen', 'den', 'blaa', 'der', 'synes'],
#      'syllables': None,
#      'last_token': 'synes',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'saa nær, saa nær,',
#      'transcription': '',
#      'tokens': ['saa', 'nær', 'saa', 'nær'],
#      'syllables': None,
#      'last_token': 'nær',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'er sket et Under: de hvide blomstrende',
#      'transcription': '',
#      'tokens': ['er', 'sket', 'et', 'under', 'de', 'hvide', 'blomstrende'],
#      'syllables': None,
#      'last_token': 'blomstrende',
#      'rhymes_with': None,
#      'verse_id': 2},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'b',
#      'text': 'Mandeltrær.',
#      'transcription': '',
#      'tokens': ['mandeltrær'],
#      'syllables': None,
#      'last_token': 'mandeltrær',
#      'rhymes_with': 1,
#      'verse_id': 3}]},
#   {'stanza_id': 1,
#    'rhyme_scheme': 'abcb',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'For aldrig saa jeg dog før paa Jorden',
#      'transcription': '',
#      'tokens': ['for', 'aldrig', 'saa', 'jeg', 'dog', 'før', 'paa', 'jorden'],
#      'syllables': None,
#      'last_token': 'jorden',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'et Syn saa hvidt,',
#      'transcription': '',
#      'tokens': ['et', 'syn', 'saa', 'hvidt'],
#      'syllables': None,
#      'last_token': 'hvidt',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'det dufter af dem i Morgensolen,',
#      'transcription': '',
#      'tokens': ['det', 'dufter', 'af', 'dem', 'i', 'morgensolen'],
#      'syllables': None,
#      'last_token': 'morgensolen',
#      'rhymes_with': None,
#      'verse_id': 2},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'b',
#      'text': 'men ganske lidt.',
#      'transcription': '',
#      'tokens': ['men', 'ganske', 'lidt'],
#      'syllables': None,
#      'last_token': 'lidt',
#      'rhymes_with': 1,
#      'verse_id': 3}]},
#   {'stanza_id': 2,
#    'rhyme_scheme': 'abcb',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'Det skinner af dem, til alle Tanker',
#      'transcription': '',
#      'tokens': ['det', 'skinner', 'af', 'dem', 'til', 'alle', 'tanker'],
#      'syllables': None,
#      'last_token': 'tanker',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'sig vider ud',
#      'transcription': '',
#      'tokens': ['sig', 'vider', 'ud'],
#      'syllables': None,
#      'last_token': 'ud',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'og majestætisk et Tempel hvælver',
#      'transcription': '',
#      'tokens': ['og', 'majestætisk', 'et', 'tempel', 'hvælver'],
#      'syllables': None,
#      'last_token': 'hvælver',
#      'rhymes_with': None,
#      'verse_id': 2},
#     {'rhyme_score': 0.5,
#      'rhyme_tag': 'b',
#      'text': 'i Tak til Gud, ‒',
#      'transcription': '',
#      'tokens': ['i', 'tak', 'til', 'gud'],
#      'syllables': None,
#      'last_token': 'gud',
#      'rhymes_with': 1,
#      'verse_id': 3}]},
#   {'stanza_id': 3,
#    'rhyme_scheme': 'abcb',
#    'verses': [{'rhyme_score': 0,
#      'rhyme_tag': 'a',
#      'text': 'hvor Engle svæver, hvor Længsler bruser',
#      'transcription': '',
#      'tokens': ['hvor', 'engle', 'svæver', 'hvor', 'længsler', 'bruser'],
#      'syllables': None,
#      'last_token': 'bruser',
#      'rhymes_with': None,
#      'verse_id': 0},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'b',
#      'text': 'i nyfødt Sang,',
#      'transcription': '',
#      'tokens': ['i', 'nyfødt', 'sang'],
#      'syllables': None,
#      'last_token': 'sang',
#      'rhymes_with': None,
#      'verse_id': 1},
#     {'rhyme_score': 0,
#      'rhyme_tag': 'c',
#      'text': 'min Sjæl forklares, og se, jeg knæler',
#      'transcription': '',
#      'tokens': ['min', 'sjæl', 'forklares', 'og', 'se', 'jeg', 'knæler'],
#      'syllables': None,
#      'last_token': 'knæler',
#      'rhymes_with': None,
#      'verse_id': 2},
#     {'rhyme_score': 1,
#      'rhyme_tag': 'b',
#      'text': 'for første Gang.',
#      'transcription': '',
#      'tokens': ['for', 'første', 'gang'],
#      'syllables': None,
#      'last_token': 'gang',
#      'rhymes_with': 1,
#      'verse_id': 3}]}]]
